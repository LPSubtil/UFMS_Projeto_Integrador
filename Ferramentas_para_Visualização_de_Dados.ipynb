# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
df_eleitores = pd.read_csv('/content/drive/MyDrive/2024.2/PROJETO INTEGRADOR II/ETAPA - COLETA E ORGANIZAÇÃO DE DADOS/perfil_selecionado_eleitor.csv')

# %% [markdown]
# #DATAFRAME LOCAIS DE VOTAÇÃO

# %%
df_eleitores.head()
# Out:
#          NM_LOCAL_VOTACAO  DS_GENERO DS_ESTADO_CIVIL DS_FAIXA_ETARIA  \
# 0  EE  VESPASIANO MARTINS  MASCULINO        SOLTEIRO    45 a 59 anos
# 1  EE  VESPASIANO MARTINS   FEMININO        SOLTEIRO    35 a 44 anos
# 2  EE  VESPASIANO MARTINS   FEMININO          CASADO    70 a 79 anos
# 3  EE  VESPASIANO MARTINS  MASCULINO        SOLTEIRO    18 a 20 anos
# 4  EE  VESPASIANO MARTINS  MASCULINO        SOLTEIRO    45 a 59 anos
#
#             DS_GRAU_ESCOLARIDADE    DS_RACA_COR DS_IDENTIDADE_GENERO  \
# 0  ENSINO FUNDAMENTAL INCOMPLETO  NÃO INFORMADO        NÃO INFORMADO
# 1            SUPERIOR INCOMPLETO         Branca            Cisgênero
# 2                     ANALFABETO  NÃO INFORMADO        NÃO INFORMADO
# 3        ENSINO MÉDIO INCOMPLETO  NÃO INFORMADO        NÃO INFORMADO
# 4        ENSINO MÉDIO INCOMPLETO  NÃO INFORMADO        NÃO INFORMADO
#
#    DS_QUILOMBOLA                                           ENDERECO
# ...

# %%
df_eleitores.columns
# Out:
# Index(['NM_LOCAL_VOTACAO', 'DS_GENERO', 'DS_ESTADO_CIVIL', 'DS_FAIXA_ETARIA',
#        'DS_GRAU_ESCOLARIDADE', 'DS_RACA_COR', 'DS_IDENTIDADE_GENERO',
#        'DS_QUILOMBOLA', 'ENDERECO'],
#       dtype='object')

# %%
#excluindo linhas vazias
df_eleitores = df_eleitores.dropna()

# %% [markdown]
# #DATAFRAME - CAMARA MUNICIPAL DE AMAMBAI
# --> Para o local de votação: CAMARA MUNICIPAL DE AMAMBAI

# %%
#Fazendo a contagem de numero de eleitores para o local de votação: CAMARA MUNICIPAL DE AMAMBAI
df_filtrado = df_eleitores[df_eleitores['NM_LOCAL_VOTACAO']=='CAMARA MUNICIPAL DE AMAMBAI']
df_filtrado.head()
# Out:
#                 NM_LOCAL_VOTACAO  DS_GENERO DS_ESTADO_CIVIL DS_FAIXA_ETARIA  \
# 592  CAMARA MUNICIPAL DE AMAMBAI  MASCULINO        SOLTEIRO         17 anos
# 593  CAMARA MUNICIPAL DE AMAMBAI  MASCULINO        SOLTEIRO    18 a 20 anos
# 594  CAMARA MUNICIPAL DE AMAMBAI  MASCULINO        SOLTEIRO    21 a 24 anos
# 595  CAMARA MUNICIPAL DE AMAMBAI  MASCULINO        SOLTEIRO    21 a 24 anos
# 596  CAMARA MUNICIPAL DE AMAMBAI  MASCULINO        SOLTEIRO    35 a 44 anos
#
#               DS_GRAU_ESCOLARIDADE    DS_RACA_COR DS_IDENTIDADE_GENERO  \
# 592        ENSINO MÉDIO INCOMPLETO         Branca            Cisgênero
# 593  ENSINO FUNDAMENTAL INCOMPLETO         Branca            Cisgênero
# 594        ENSINO MÉDIO INCOMPLETO  NÃO INFORMADO        NÃO INFORMADO
# 595          ENSINO MÉDIO COMPLETO         Branca            Cisgênero
# 596          ENSINO MÉDIO COMPLETO          Parda            Cisgênero
#
#      DS_QUILOMBOLA                                           ENDERECO
# ...

# %%
#contagem de eleitores por faixa etária
contagem = df_filtrado.groupby(['DS_FAIXA_ETARIA']).size().reset_index(name='contagem')
contagem
# Out:
#       DS_FAIXA_ETARIA  contagem
# 0             16 anos         4
# 1             17 anos         3
# 2        18 a 20 anos        21
# 3        21 a 24 anos        26
# 4        25 a 34 anos        48
# 5        35 a 44 anos        77
# 6        45 a 59 anos        99
# 7        60 a 69 anos        69
# 8        70 a 79 anos        41
# 9  Superior a 79 anos        20

# %%
#Plot gráfico de barras

plt.figure(figsize=(8, 6))

plt.bar(contagem['DS_FAIXA_ETARIA'], contagem['contagem'], color = 'darkseagreen')
plt.xlabel('Faixa Etária',fontsize=14)
plt.ylabel('Contagem de Eleitores',fontsize=14)
plt.title('Contagem de Eleitores por Faixa Etária',fontsize=16, fontweight='bold')
plt.xticks(rotation=45,fontsize=9)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##CAMARA MUNICIPAL DE AMAMBAI - *FEMININO*

# %%
# Filtrando o DataFrame para o Gênero Feminino
gen_fem_df = df_filtrado[
    (df_filtrado['DS_GENERO'] == 'FEMININO')]


gen_fem_df.head()
# Out:
#                 NM_LOCAL_VOTACAO DS_GENERO DS_ESTADO_CIVIL DS_FAIXA_ETARIA  \
# 600  CAMARA MUNICIPAL DE AMAMBAI  FEMININO        SOLTEIRO    18 a 20 anos
# 601  CAMARA MUNICIPAL DE AMAMBAI  FEMININO        SOLTEIRO    21 a 24 anos
# 602  CAMARA MUNICIPAL DE AMAMBAI  FEMININO        SOLTEIRO    60 a 69 anos
# 603  CAMARA MUNICIPAL DE AMAMBAI  FEMININO      DIVORCIADO    45 a 59 anos
# 738  CAMARA MUNICIPAL DE AMAMBAI  FEMININO        SOLTEIRO    18 a 20 anos
#
#               DS_GRAU_ESCOLARIDADE    DS_RACA_COR DS_IDENTIDADE_GENERO  \
# 600        ENSINO MÉDIO INCOMPLETO  NÃO INFORMADO        NÃO INFORMADO
# 601          ENSINO MÉDIO COMPLETO  NÃO INFORMADO        NÃO INFORMADO
# 602          ENSINO MÉDIO COMPLETO  NÃO INFORMADO        NÃO INFORMADO
# 603  ENSINO FUNDAMENTAL INCOMPLETO  NÃO INFORMADO        NÃO INFORMADO
# 738          ENSINO MÉDIO COMPLETO         Branca            Cisgênero
#
#      DS_QUILOMBOLA                                           ENDERECO
# ...

# %% [markdown]
# ###*FEMININO-FAIXA_ETÁRIA*

# %%
# Agrupar por DS_FAIXA_ETARIA
grouped_df_fem2 = gen_fem_df.groupby(['DS_FAIXA_ETARIA']).size().reset_index(name='counts')

print(grouped_df_fem2)
# Out:
#       DS_FAIXA_ETARIA  counts
# 0             16 anos       2
# 1             17 anos       1
# 2        18 a 20 anos      13
# 3        21 a 24 anos      12
# 4        25 a 34 anos      29
# 5        35 a 44 anos      41
# 6        45 a 59 anos      51
# 7        60 a 69 anos      37
# 8        70 a 79 anos      21
# 9  Superior a 79 anos      11

# %%
grouped_df_fem2.sum()
# Out:
# DS_FAIXA_ETARIA    16 anos17 anos18 a 20 anos21 a 24 anos25 a 34 ...
# counts                                                           218
# dtype: object

# %%
plot_fem = pd.DataFrame(grouped_df_fem2)

# Criando o gráfico
plt.figure(figsize=(8, 6))
plt.bar(plot_fem['DS_FAIXA_ETARIA'], plot_fem['counts'], color='pink')
plt.xlabel('Faixa Etária',fontsize=14)
plt.ylabel('Contagem',fontsize=14)
plt.title('Distribuição de Faixa Etária',fontsize=16, fontweight='bold')
plt.xticks(rotation=45, fontsize=9)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ###*FEMININO-GRAU_ESCOLARIDADE*

# %%
# Agrupar por DS_GRAU_ESCOLARIDADE
grouped_df_fem3 = gen_fem_df.groupby(['DS_GRAU_ESCOLARIDADE']).size().reset_index(name='counts')

print(grouped_df_fem3)
# Out:
#             DS_GRAU_ESCOLARIDADE  counts
# 0                     ANALFABETO      10
# 1    ENSINO FUNDAMENTAL COMPLETO      15
# 2  ENSINO FUNDAMENTAL INCOMPLETO      33
# 3          ENSINO MÉDIO COMPLETO      52
# 4        ENSINO MÉDIO INCOMPLETO      19
# 5                   LÊ E ESCREVE      18
# 6              SUPERIOR COMPLETO      49
# 7            SUPERIOR INCOMPLETO      22

# %%
plot_fem2 = pd.DataFrame(grouped_df_fem3)

# Criando o gráfico
plt.figure(figsize=(8, 6))
plt.bar(plot_fem2['DS_GRAU_ESCOLARIDADE'], plot_fem2['counts'], color='pink')
plt.xlabel('Grau de Escolaridade',fontsize=14)
plt.ylabel('Contagem',fontsize=14)
plt.title('Grau de Escolaridade - FEMININO ',fontsize=16, fontweight='bold')
plt.xticks(rotation=90,fontsize=9)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ###FEMININO - ESTADO_CIVIL

# %%
# Agrupar por DS_ESTADO_CIVIL
civil_df_fem = gen_fem_df.groupby(['DS_ESTADO_CIVIL']).size().reset_index(name='counts')

print(civil_df_fem)
# Out:
#           DS_ESTADO_CIVIL  counts
# 0                  CASADO      82
# 1              DIVORCIADO      22
# 2  SEPARADO JUDICIALMENTE      11
# 3                SOLTEIRO      93
# 4                   VIÚVO      10

# %%
plot_fem3 = pd.DataFrame(civil_df_fem)


# Criando o gráfico
plt.figure(figsize=(6, 4))

plt.bar(plot_fem3['DS_ESTADO_CIVIL'], plot_fem3['counts'], color='sandybrown')
plt.xlabel('Estado Civil', fontsize=14)
plt.ylabel('Contagem', fontsize=14)
plt.title('Estado Civil - FEMININO ', fontsize=16, fontweight='bold')
plt.xticks(rotation=90,  fontsize=9)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##CAMARA MUNICIPAL DE AMAMBAI - *MASCULINO*

# %%
# Filtrando o DataFrame para o Gênero Masculino
gen_masc_df = df_filtrado[
    (df_filtrado['DS_GENERO'] == 'MASCULINO')]


gen_masc_df.head()
# Out:
#                 NM_LOCAL_VOTACAO  DS_GENERO DS_ESTADO_CIVIL DS_FAIXA_ETARIA  \
# 592  CAMARA MUNICIPAL DE AMAMBAI  MASCULINO        SOLTEIRO         17 anos
# 593  CAMARA MUNICIPAL DE AMAMBAI  MASCULINO        SOLTEIRO    18 a 20 anos
# 594  CAMARA MUNICIPAL DE AMAMBAI  MASCULINO        SOLTEIRO    21 a 24 anos
# 595  CAMARA MUNICIPAL DE AMAMBAI  MASCULINO        SOLTEIRO    21 a 24 anos
# 596  CAMARA MUNICIPAL DE AMAMBAI  MASCULINO        SOLTEIRO    35 a 44 anos
#
#               DS_GRAU_ESCOLARIDADE    DS_RACA_COR DS_IDENTIDADE_GENERO  \
# 592        ENSINO MÉDIO INCOMPLETO         Branca            Cisgênero
# 593  ENSINO FUNDAMENTAL INCOMPLETO         Branca            Cisgênero
# 594        ENSINO MÉDIO INCOMPLETO  NÃO INFORMADO        NÃO INFORMADO
# 595          ENSINO MÉDIO COMPLETO         Branca            Cisgênero
# 596          ENSINO MÉDIO COMPLETO          Parda            Cisgênero
#
#      DS_QUILOMBOLA                                           ENDERECO
# ...

# %% [markdown]
# ### *MASCULINO-FAIXA_ETÁRIA*

# %%
# Agrupar por DS_FAIXA_ETARIA
grouped_df_masc = gen_masc_df.groupby(['DS_FAIXA_ETARIA']).size().reset_index(name='counts')

print(grouped_df_masc)
# Out:
#       DS_FAIXA_ETARIA  counts
# 0             16 anos       2
# 1             17 anos       2
# 2        18 a 20 anos       8
# 3        21 a 24 anos      14
# 4        25 a 34 anos      19
# 5        35 a 44 anos      36
# 6        45 a 59 anos      48
# 7        60 a 69 anos      32
# 8        70 a 79 anos      20
# 9  Superior a 79 anos       9

# %%
plot_masc = pd.DataFrame(grouped_df_masc)

# Criando o gráfico
plt.figure(figsize=(8, 6))
plt.bar(plot_masc['DS_FAIXA_ETARIA'], plot_masc['counts'], color='skyblue')
plt.xlabel('Faixa Etária', fontsize=14)
plt.ylabel('Contagem', fontsize=14)
plt.title('Distribuição de Faixa Etária', fontsize=16, fontweight='bold' )
plt.xticks(rotation=90, fontsize=9)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### *MASCULINO-GRAU_ESCOLARIDADE*

# %%
# Agrupar por DS_GRAU_ESCOLARIDADE
grouped_df_masc2 = gen_masc_df.groupby(['DS_GRAU_ESCOLARIDADE']).size().reset_index(name='counts')

print(grouped_df_masc2)
# Out:
#             DS_GRAU_ESCOLARIDADE  counts
# 0                     ANALFABETO      10
# 1    ENSINO FUNDAMENTAL COMPLETO      13
# 2  ENSINO FUNDAMENTAL INCOMPLETO      36
# 3          ENSINO MÉDIO COMPLETO      41
# 4        ENSINO MÉDIO INCOMPLETO      25
# 5                   LÊ E ESCREVE      17
# 6              SUPERIOR COMPLETO      32
# 7            SUPERIOR INCOMPLETO      16

# %%
plot_masc2 = pd.DataFrame(grouped_df_masc2)

# Criando o gráfico
plt.figure(figsize=(8, 5))
plt.bar(plot_masc2['DS_GRAU_ESCOLARIDADE'], plot_masc2['counts'], color='deepskyblue')
plt.xlabel('Grau de Escolaridade', fontsize=14)
plt.ylabel('Contagem', fontsize=14)
plt.title('Grau de Escolaridade - MASCULINO', fontsize=16, fontweight='bold' )
plt.xticks(rotation=90, fontsize=9)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### MASCULINO - ESTADO_CIVIL

# %%
# Agrupar por DS_ESTADO_CIVIL
civil_df_masc = gen_masc_df.groupby(['DS_ESTADO_CIVIL']).size().reset_index(name='counts')

print(civil_df_masc)
# Out:
#           DS_ESTADO_CIVIL  counts
# 0                  CASADO      77
# 1              DIVORCIADO      12
# 2  SEPARADO JUDICIALMENTE       3
# 3                SOLTEIRO      92
# 4                   VIÚVO       6

# %%
plot_masc3 = pd.DataFrame(civil_df_masc)


# Criando o gráfico
plt.figure(figsize=(6, 4))

plt.bar(plot_masc3['DS_ESTADO_CIVIL'], plot_masc3['counts'], color='saddlebrown')
plt.xlabel('Estado Civil', fontsize=14)
plt.ylabel('Contagem', fontsize=14)
plt.title('Estado Civil - MASCULINO ', fontsize=16, fontweight='bold')
plt.xticks(rotation=90,  fontsize=9)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##COMPARAÇÃO FEMININO VS. MASCULINO

# %%
grouped_df_fem2.sum()
# Out:
# DS_FAIXA_ETARIA    16 anos17 anos18 a 20 anos21 a 24 anos25 a 34 ...
# counts                                                           218
# dtype: object

# %%
grouped_df_masc.sum()
# Out:
# DS_FAIXA_ETARIA    16 anos17 anos18 a 20 anos21 a 24 anos25 a 34 ...
# counts                                                           190
# dtype: object

# %% [markdown]
# ###COMPARAÇÃO FAIXA ETÁRIA

# %%
plot_masc = pd.DataFrame(grouped_df_masc)
plot_fem = pd.DataFrame(grouped_df_fem2)


# Convertendo dados em numpy arrays para facilitar manipulação
labels = plot_fem['DS_FAIXA_ETARIA']
fem_counts = np.array(plot_fem['counts'])
masc_counts = np.array(plot_masc['counts'])

# Definindo a largura das barras
width = 0.35

# Definindo a posição das barras
x = np.arange(len(labels))

plt.figure(figsize=(8, 4))

# Plotando as barras
plt.bar(x - width/2, fem_counts, width, label='Feminino', color='tomato', alpha=0.7)
plt.bar(x + width/2, masc_counts, width, label='Masculino', color='cyan', alpha=0.7)

# Adicionando os detalhes do gráfico
plt.xlabel('Faixa Etária', fontsize=12)
plt.ylabel('Contagem', fontsize=12)
plt.title('Distribuição de Faixa Etária por Gênero', fontsize=16, fontweight='bold')
plt.xticks(x, labels, rotation=90, fontsize=9)
plt.yticks(fontsize=9)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ####Estatistica Descritiva - FEMININO

# %% [markdown]
# #####Pontos Médios

# %% [markdown]
# -> Para simplificar o cálculo de estatísticas descritivas, as idades foram reprsentadas pelos pontos médios de cada faixa etária. Essa escolha facilta os calculos subsequentes.

# %%
pontos_medios_fem = pd.DataFrame(grouped_df_fem2)
pontos_medios_fem
# Out:
#       DS_FAIXA_ETARIA  counts
# 0             16 anos       2
# 1             17 anos       1
# 2        18 a 20 anos      13
# 3        21 a 24 anos      12
# 4        25 a 34 anos      29
# 5        35 a 44 anos      41
# 6        45 a 59 anos      51
# 7        60 a 69 anos      37
# 8        70 a 79 anos      21
# 9  Superior a 79 anos      11

# %%
#dicionário para mapear as faixas etárias para valores numéricos
faixa_etaria_map = {
    '16 anos': 16,
    '17 anos': 17,
    '18 a 20 anos': 19,  # Valor médio da faixa
    '21 a 24 anos': 22.5,  # Valor médio da faixa
    '25 a 34 anos': 29.5,  # Valor médio da faixa
    '35 a 44 anos': 39.5,  # Valor médio da faixa
    '45 a 59 anos': 52,  # Valor médio da faixa
    '60 a 69 anos': 64.5,  # Valor médio da faixa
    '70 a 79 anos': 74.5,  # Valor médio da faixa
    'Superior a 79 anos': 80  # Valor representativo
}

# %%
# Substituir as faixas etárias pelos valores numéricos
pontos_medios_fem['faixa_etaria'] = pontos_medios_fem['DS_FAIXA_ETARIA'].map(faixa_etaria_map)

# %%
pontos_medios_fem
# Out:
#       DS_FAIXA_ETARIA  counts  faixa_etaria   multp
# 0             16 anos       2          16.0    32.0
# 1             17 anos       1          17.0    17.0
# 2        18 a 20 anos      13          19.0   247.0
# 3        21 a 24 anos      12          22.5   270.0
# 4        25 a 34 anos      29          29.5   855.5
# 5        35 a 44 anos      41          39.5  1619.5
# 6        45 a 59 anos      51          52.0  2652.0
# 7        60 a 69 anos      37          64.5  2386.5
# 8        70 a 79 anos      21          74.5  1564.5
# 9  Superior a 79 anos      11          80.0   880.0

# %% [markdown]
# #####Média

# %%
# Acrescentando a coluna 'multp', que é a multiplicação da coluna 'faixa_etaria' com 'counts'
pontos_medios_fem['multp'] = pontos_medios_fem['faixa_etaria']*pontos_medios_fem['counts']
pontos_medios_fem
# Out:
#       DS_FAIXA_ETARIA  counts  faixa_etaria   multp
# 0             16 anos       2          16.0    32.0
# 1             17 anos       1          17.0    17.0
# 2        18 a 20 anos      13          19.0   247.0
# 3        21 a 24 anos      12          22.5   270.0
# 4        25 a 34 anos      29          29.5   855.5
# 5        35 a 44 anos      41          39.5  1619.5
# 6        45 a 59 anos      51          52.0  2652.0
# 7        60 a 69 anos      37          64.5  2386.5
# 8        70 a 79 anos      21          74.5  1564.5
# 9  Superior a 79 anos      11          80.0   880.0

# %%
# Calculando a divisão da soma total de 'multp' pela soma total de 'counts'
media_fem = pontos_medios_fem['multp'].sum() / pontos_medios_fem['counts'].sum()

print(media_fem)
# Out:
# 48.27522935779817

# %% [markdown]
# #####Mediana

# %%
# Ordenar o dataframe pela coluna 'counts'
pontos_medios_fem_sorted = pontos_medios_fem.sort_values(by='counts').reset_index(drop=True)
pontos_medios_fem_sorted
# Out:
#       DS_FAIXA_ETARIA  counts  faixa_etaria   multp
# 0             17 anos       1          17.0    17.0
# 1             16 anos       2          16.0    32.0
# 2  Superior a 79 anos      11          80.0   880.0
# 3        21 a 24 anos      12          22.5   270.0
# 4        18 a 20 anos      13          19.0   247.0
# 5        70 a 79 anos      21          74.5  1564.5
# 6        25 a 34 anos      29          29.5   855.5
# 7        60 a 69 anos      37          64.5  2386.5
# 8        35 a 44 anos      41          39.5  1619.5
# 9        45 a 59 anos      51          52.0  2652.0

# %%
# Como são 10 faixas (par)  o valor da mediana é baseado nas faixas etárias que estão nas posições 4 e 5
# Fazer calculo dos dados dos index 4 e 5
soma_multp1 = pontos_medios_fem_sorted.loc[4, 'multp'] + pontos_medios_fem_sorted.loc[5, 'multp']

# Fazer a soma dos dados dos index 4 e 5 na coluna 'counts'
soma_counts1 = pontos_medios_fem_sorted.loc[4, 'counts'] + pontos_medios_fem_sorted.loc[5, 'counts']

# Dividir a soma da coluna 'multp' pela soma da coluna 'counts'
mediana = soma_multp1 / soma_counts1

mediana
# Out:
# 53.279411764705884

# %% [markdown]
# #####Desvio Padrão
#
# Indica o quão dispersas as idades estão em relação a média. Quanto maior o valor maior a variabilidade nas idades.

# %%
# Calcular o quadrado da diferença de cada valor em relação à média
pontos_medios_fem_sorted['desvio_p'] = (pontos_medios_fem_sorted['faixa_etaria'] - media_fem) ** 2
# Transformar a coluna 'desvio_p' em int
pontos_medios_fem_sorted['desvio_p'] = pontos_medios_fem_sorted['desvio_p'].astype(int)
pontos_medios_fem_sorted
# Out:
#       DS_FAIXA_ETARIA  counts  faixa_etaria   multp  desvio_p
# 0             17 anos       1          17.0    17.0       978
# 1             16 anos       2          16.0    32.0      1041
# 2  Superior a 79 anos      11          80.0   880.0      1006
# 3        21 a 24 anos      12          22.5   270.0       664
# 4        18 a 20 anos      13          19.0   247.0       857
# 5        70 a 79 anos      21          74.5  1564.5       687
# 6        25 a 34 anos      29          29.5   855.5       352
# 7        60 a 69 anos      37          64.5  2386.5       263
# 8        35 a 44 anos      41          39.5  1619.5        77
# 9        45 a 59 anos      51          52.0  2652.0        13

# %%
#Calcular as diferenças ao quadrado
soma_diferencas_quad = pontos_medios_fem_sorted['desvio_p'].sum()
soma_diferencas_quad
# Out:
# 5938

# %%
#Dividir a soma pelo número total de idades

variancia_fem = soma_diferencas_quad / pontos_medios_fem_sorted['counts'].sum()
variancia_fem
# Out:
# 27.238532110091743

# %%
#Calcular o desvio padrão
desvio_padrao_fem = variancia_fem**0.5
desvio_padrao_fem
# Out:
# 5.219054714226681

# %% [markdown]
# #####Describe

# %%
#resumo estatístico da coluna faixa_etaria que está representada pelo ponto médio
resumo_fem = pontos_medios_fem_sorted['faixa_etaria'].describe()
resumo_fem
# Out:
# count    10.000000
# mean     41.450000
# std      24.667173
# min      16.000000
# 25%      19.875000
# 50%      34.500000
# 75%      61.375000
# max      80.000000
# Name: faixa_etaria, dtype: float64

# %% [markdown]
# ####Estatistica Descritiva - MASCULINO

# %%
pontos_medios_masc = pd.DataFrame(grouped_df_masc)
pontos_medios_masc

# %%
# Substituir as faixas etárias pelos valores numéricos
pontos_medios_masc['faixa_etaria'] = pontos_medios_masc['DS_FAIXA_ETARIA'].map(faixa_etaria_map)
pontos_medios_masc

# %%
# Acrescentando a coluna 'multp', que é a multiplicação da coluna 'faixa_etaria' com 'counts'
pontos_medios_masc['multp'] = pontos_medios_masc['faixa_etaria']*pontos_medios_masc['counts']
pontos_medios_masc

# %% [markdown]
# #####Média

# %%
# Calculando a divisão da soma total de 'multp' pela soma total de 'counts'
media_masc = pontos_medios_masc['multp'].sum() / pontos_medios_masc['counts'].sum()

print(media_masc)
# Out:
# 48.87105263157895

# %% [markdown]
# #####Mediana

# %%
# Ordenar o dataframe pela coluna 'counts'
pontos_medios_masc_sorted = pontos_medios_masc.sort_values(by='counts').reset_index(drop=True)
pontos_medios_masc_sorted

# %%
# Como são 10 faixas (par)  o valor da mediana é baseado nas faixas etárias que estão nas posições 4 e 5
# Fazer a soma dos dados dos index 4 e 5 na coluna 'multp'
soma_multp2 = pontos_medios_masc_sorted.loc[4, 'multp'] + pontos_medios_masc_sorted.loc[5, 'multp']

# Fazer a soma dos dados dos index 4 e 5 na coluna 'counts'
soma_counts2 = pontos_medios_masc_sorted.loc[4, 'counts'] + pontos_medios_masc_sorted.loc[5, 'counts']

# Dividir a soma da coluna 'multp' pela soma da coluna 'counts'
mediana2 = soma_multp2 / soma_counts2

mediana2

# %% [markdown]
# #####Desvio Padrão

# %%
# Calcular o quadrado da diferença de cada valor em relação à média
pontos_medios_masc_sorted['desvio_p'] = (pontos_medios_masc_sorted['faixa_etaria'] - media_masc) ** 2
# Transformar a coluna 'desvio_p' em int
pontos_medios_masc_sorted['desvio_p'] = pontos_medios_masc_sorted['desvio_p'].astype(int)
pontos_medios_masc_sorted
# Out:
#       DS_FAIXA_ETARIA  counts  faixa_etaria   multp  desvio_p
# 0             16 anos       2          16.0    32.0      1080
# 1             17 anos       2          17.0    34.0      1015
# 2        18 a 20 anos       8          19.0   152.0       892
# 3  Superior a 79 anos       9          80.0   720.0       969
# 4        21 a 24 anos      14          22.5   315.0       695
# 5        25 a 34 anos      19          29.5   560.5       375
# 6        70 a 79 anos      20          74.5  1490.0       656
# 7        60 a 69 anos      32          64.5  2064.0       244
# 8        35 a 44 anos      36          39.5  1422.0        87
# 9        45 a 59 anos      48          52.0  2496.0         9

# %%
soma_diferencas_quad2 = pontos_medios_masc_sorted['desvio_p'].sum()
soma_diferencas_quad2
# Out:
# 6022

# %%
#Dividir a soma pelo número total de idades

variancia2 = soma_diferencas_quad2 / pontos_medios_masc_sorted['counts'].sum()
variancia2
# Out:
# 31.694736842105264

# %%
#Calcular o desvio padrão
desvio_padrao_masc = variancia2**0.5
desvio_padrao_masc
# Out:
# 5.629807886784882

# %% [markdown]
# #####Describe

# %%
#resumo estatístico da coluna faixa_etaria que está representada pelo ponto médio
resumo_masc = pontos_medios_masc_sorted['faixa_etaria'].describe()
resumo_masc
# Out:
# count    10.000000
# mean     41.450000
# std      24.667173
# min      16.000000
# 25%      19.875000
# 50%      34.500000
# 75%      61.375000
# max      80.000000
# Name: faixa_etaria, dtype: float64

# %% [markdown]
# ###COMPARAÇÃO GRAU ESCOLARIDADE

# %%
# Convertendo dados em numpy arrays para facilitar manipulação
labels = plot_fem2['DS_GRAU_ESCOLARIDADE']
fem_counts = np.array(plot_fem2['counts'])
masc_counts = np.array(plot_masc2['counts'])

# Definindo a largura das barras
width = 0.35

# Definindo a posição das barras
x = np.arange(len(labels))

plt.figure(figsize=(10, 6))

# Plotando as barras
plt.bar(x - width/2, fem_counts, width, label='Feminino', color='fuchsia', alpha=0.7)
plt.bar(x + width/2, masc_counts, width, label='Masculino', color='deepskyblue', alpha=0.7)

# Adicionando os detalhes do gráfico
plt.xlabel('Grau de Escolaridade', fontsize=12)
plt.ylabel('Contagem', fontsize=12)
plt.title('Distribuição de Grau de Escolaridade por Gênero', fontsize=16, fontweight='bold')
plt.xticks(x, labels, rotation=90, fontsize=9)
plt.yticks(fontsize=9)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ###COMPARAÇÃO ESTADO CIVIL

# %%
plot_fem3 = pd.DataFrame(civil_df_fem)
plot_masc3 = pd.DataFrame(civil_df_masc)

# Convertendo dados em numpy arrays para facilitar manipulação
labels = plot_fem3['DS_ESTADO_CIVIL']
fem_counts3 = np.array(plot_fem3['counts'])
masc_counts3 = np.array(plot_masc3['counts'])

# Definindo a largura das barras
width = 0.35

# Definindo a posição das barras
x = np.arange(len(labels))

plt.figure(figsize=(8, 6))

# Plotando as barras
plt.bar(x - width/2, fem_counts3, width, label='Feminino', color='sandybrown', alpha=0.7)
plt.bar(x + width/2, masc_counts3, width, label='Masculino', color='saddlebrown', alpha=0.7)

# Adicionando os detalhes do gráfico
plt.xlabel('Estado Civil', fontsize=12)
plt.ylabel('Contagem', fontsize=12)
plt.title('Distribuição de Estado Civil por Gênero', fontsize=16, fontweight='bold')
plt.xticks(x, labels, rotation=90, fontsize=9)
plt.yticks(fontsize=9)
plt.legend()
plt.tight_layout()
plt.show()
